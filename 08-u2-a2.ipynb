# %% [markdown]
# ## U2_A2

# %%
meu_conjunto = set()

# %%
meu_conjunto.add(10)

# %%
meu_conjunto.add(20)
meu_conjunto.add(30)

# %%
meu_conjunto.add(10) # Não tem repeticão.

# %%
meu_conjunto

# %%
meu_conjunto.remove(20)

# %%
elemento = 20
if elemento in meu_conjunto:
  print(f"O elemento {elemento} está no meu conjunto!")
else:
  print(f"O elemento {elemento} não está no meu conjunto!")

# %%
numeros_com_repeticao = [1,2,2,4,5,5,7,7,8,]

# %%
unicos = set(numeros_com_repeticao)

# %%
numeros_com_repeticao

# %%
unicos

# %%
dici_1 = {}

# %%
dici_1['name'] = "Aluno"

# %%
dici_1['idade'] = 25

# %%
dici_1

# %%
dici_2 = {'name': 'Aluno', 'idade' : 25}

# %%
dici_2

# %%
dici_3 = dict(name = 'Ronlado', idade = 25)

# %%
dici_3

# %%
dici_4 = dict(zip(['name', 'idade'], ['Ronalo', 25]))

# %%
dici_4

# %%
import numpy as np
my_array = np.array([1,2,3,4,5])
print(my_array)

# %%
squared_array = my_array ** 2
print("\nArray ao quadrado:")

print(squared_array)

# %%
sum_of_elements = np.sum(my_array)
print("\nSoma dos elementos:")

print(sum_of_elements)

# %%
element_at_index_2 = my_array[2]
print("\nElementos no índice 2")
print(element_at_index_2)

# %%
# Importa a biblioteca NumPy
import numpy as np

# Dados dos participantes
participantes = [
    {
        "nome": "Alice",
        "localizacao": "EUA",
        "afiliacao": "Universidade A",
        "interesses": ["Fisica", "Astronomia"]
    },
    {
        "nome": "Bob",
        "localizacao": "Brasil",
        "afiliacao": "Instituto B",
        "interesses": ["Biologia", "Astronomia"]
    },
    {
        "nome": "Charlie",
        "localizacao": "India",
        "afiliacao": "Instituto C",
        "interesses": ["Quimica", "Engenharia"]
    }
]

# Usando set para identificar as diferentes regiões
regioes = set(
    participante["localizacao"]
    for participante in participantes
)

# Usando dicionário para categorizar as afiliações
afiliacoes = {}

for participante in participantes:
    afiliacao = participante["afiliacao"]

    if afiliacao not in afiliacoes:
        afiliacoes[afiliacao] = []

    afiliacoes[afiliacao].append(participante["nome"])

# Usando NumPy para analisar as áreas de interesse
areas_de_interesse = np.array([
    interesse
    for participante in participantes
    for interesse in participante["interesses"]
])

# Encontra os interesses únicos e suas quantidades
interesses_unicos, contagem = np.unique(
    areas_de_interesse,
    return_counts=True
)

# Encontra o interesse que apareceu mais vezes
area_mais_popular = interesses_unicos[np.argmax(contagem)]

# Exibe os resultados
print("Regiões dos participantes:", regioes)

print("\nAfiliações dos participantes:")

for afiliacao, nomes in afiliacoes.items():
    print(f"{afiliacao}: {', '.join(nomes)}")

print("\nÁrea de interesse mais popular:", area_mais_popular)
