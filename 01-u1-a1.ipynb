# %% [markdown]
# ##U1_A1

# %%
# Nosso primeiro programa.
print("Hello, world!")

# %%
# Criando variveis de tipos diferentes.
x = 10
name = 'Aluno'
nota = 8.5
Fez_a_inscriçao = True

# %%
print(x)
print(name)
print(nota)
print(Fez_a_inscriçao)

# %%
print(type(x))
print(type(name))
print(type(nota))
print(type(Fez_a_inscriçao))

# %%
name = input("Digite seu nome: ")
print(f"Olá {name}, Bem vindo a disciplina de Programação.")

# %%
NOTA_1 = float(input("Digite a nota 1: "))
NOTA_2 = float(input("Digite a nota 2: "))
NOTA_3 = float(input("Digite a nota 3: "))

NOTA_4 = float(input("Digite a nota 4: "))

MEDIA = (NOTA_1 + NOTA_2 + NOTA_3 + NOTA_4) / 4
print(f"A média do aluno é: {MEDIA}")

# %%
if MEDIA >= 6:
   situaco = "APROVADO!"
else:
   situacao = "REPROVADO!"
print(situaco)
